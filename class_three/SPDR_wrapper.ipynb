# %%
import requests
def company_search(ticker):
    lookup_url = "http://www.sectorspdr.com/sectorspdr/IDCO.Client.Spdrs.Holdings/Export/ExportCsv?symbol="
    r = requests.get(lookup_url + ticker)
    print(r.text)
company_search("xlf")
# Out:
# "Holdings and weightings as of 5:36 PM ET 02/21/2017",
# "Symbol","Company Name","Index Weight","Last","Change","%Change","Volume","52 Week Range",
# "JPM","JP Morgan Chase & Co","10.82%","90.94","-0.07","-0.08%","7.07 M","54.33 - 91.15",
# "BRK.b","Berkshire Hathaway B","10.66%","169.34","+0.42","+0.25%","2.04 M","128.88 - 169.65",
# "WFC","Wells Fargo & Co","8.75%","58.38","+0.13","+0.22%","8.45 M","43.55 - 59.01",
# "BAC","Bank of America Corp","8.32%","24.78","0.00","0.00%","65.31 M","11.65 - 24.80",
# "C","Citigroup Inc","5.73%","60.76","+0.21","+0.35%","11.99 M","36.61 - 61.63",
# "GS","Goldman Sachs Group Inc","3.09%","251.43","-0.33","-0.13%","1.69 M","138.20 - 252.65",
# "USB","US Bancorp","2.93%","55.23","+0.03","+0.05%","2.97 M","37.48 - 55.37",
# "MS","Morgan Stanley","2.23%","46.51","-0.05","-0.11%","5.74 M","22.68 - 46.75",
# "CB","Chubb Limited","2.11%","137.48","+0.75","+0.55%","703.51 K","114.58 - 136.87",
# ...
